# %%
from sklearn.datasets import make_blobs

from sklearn import naive_bayes
from sklearn.naive_bayes import GaussianNB
import category_encoders as ce
from sklearn.preprocessing import StandardScaler

import numpy as np
import pandas as pd

# %%
data_train = pd.read_csv("./train.csv")
data_test = pd.read_csv("./test.csv")
print("Shape of Training Data:", data_train.shape)
print("Shape of Test Data:", data_test.shape)
test_EmpId = {}
test_EmpId = data_test["Employee ID"]
data_train.head()
# Out:
# Shape of Training Data: (22750, 9)
# Shape of Test Data: (12250, 8)
#                 Employee ID Date of Joining  Gender Company Type  \
# 0  fffe32003000360033003200         9/30/08  Female      Service
# 1      fffe3700360033003500        11/30/08    Male      Service
# 2  fffe31003300320037003900         3/10/08  Female      Product
# 3  fffe32003400380032003900         11/3/08    Male      Service
# 4  fffe31003900340031003600         7/24/08  Female      Service
#
#   WFH Setup Available  Designation  Resource Allocation  Mental Fatigue Score  \
# 0                  No            2                  3.0                   3.8
# 1                 Yes            1                  2.0                   5.0
# 2                 Yes            2                  NaN                   5.8
# 3                 Yes            1                  1.0                   2.6
# 4                  No            3                  7.0                   6.9
#
#    Happiness
# 0       0.84
# 1       0.64
# 2       0.51
# 3       0.80
# 4       0.48

# %%
data_test.head()
# Out:
#                 Employee ID Date of Joining  Gender Company Type  \
# 0  fffe31003300390039003000        12/10/08  Female      Service
# 1  fffe31003300310037003800         8/14/08  Female      Product
# 2  fffe33003400380035003900        11/13/08    Male      Product
# 3      fffe3100370039003200          2/7/08  Female      Service
# 4  fffe32003600390036003700         7/17/08  Female      Product
#
#   WFH Setup Available  Designation  Resource Allocation  Mental Fatigue Score
# 0                  No            2                    5                   7.7
# 1                 Yes            1                    2                   5.2
# 2                 Yes            1                    3                   5.9
# 3                  No            3                    6                   4.6
# 4                  No            2                    5                   6.4

# %%
data_train['HappyCond'] = np.where(data_train["Happiness"]>=0.5,1,0)
data_train.head()
# Out:
#                 Employee ID Date of Joining  Gender Company Type  \
# 0  fffe32003000360033003200         9/30/08  Female      Service
# 1      fffe3700360033003500        11/30/08    Male      Service
# 2  fffe31003300320037003900         3/10/08  Female      Product
# 3  fffe32003400380032003900         11/3/08    Male      Service
# 4  fffe31003900340031003600         7/24/08  Female      Service
#
#   WFH Setup Available  Designation  Resource Allocation  Mental Fatigue Score  \
# 0                  No            2                  3.0                   3.8
# 1                 Yes            1                  2.0                   5.0
# 2                 Yes            2                  NaN                   5.8
# 3                 Yes            1                  1.0                   2.6
# 4                  No            3                  7.0                   6.9
#
#    Happiness  HappyCond
# 0       0.84          1
# 1       0.64          1
# 2       0.51          1
# 3       0.80          1
# 4       0.48          0

# %%
print(data_train.info())
print(data_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22750 entries, 0 to 22749
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           22750 non-null  object
#  1   Date of Joining       22750 non-null  object
#  2   Gender                22750 non-null  object
#  3   Company Type          22750 non-null  object
#  4   WFH Setup Available   22750 non-null  object
#  5   Designation           22750 non-null  int64
#  6   Resource Allocation   21369 non-null  float64
#  7   Mental Fatigue Score  20633 non-null  float64
#  8   Happiness             21626 non-null  float64
#  9   HappyCond             22750 non-null  int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 1.7+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12250 entries, 0 to 12249
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           12250 non-null  object
#  1   Date of Joining       12250 non-null  object
#  2   Gender                12250 non-null  object
#  3   Company Type          12250 non-null  object
#  4   WFH Setup Available   12250 non-null  object
#  5   Designation           12250 non-null  int64
#  6   Resource Allocation   12250 non-null  int64
#  7   Mental Fatigue Score  12250 non-null  float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 765.8+ KB
# None

# %%
import datetime as dt

data_train["Date of Joining"] =  pd.to_datetime(data_train["Date of Joining"])
data_test["Date of Joining"] =  pd.to_datetime(data_test["Date of Joining"])
data_train.dtypes
# Out:
# Employee ID                     object
# Date of Joining         datetime64[ns]
# Gender                          object
# Company Type                    object
# WFH Setup Available             object
# Designation                      int64
# Resource Allocation            float64
# Mental Fatigue Score           float64
# Happiness                      float64
# HappyCond                        int64
# dtype: object

# %%
dt_today = dt.date.today()
data_train["today"]=dt_today
data_test["today"]=dt_today
data_train.head()
# Out:
#                 Employee ID Date of Joining  Gender Company Type  \
# 0  fffe32003000360033003200      2008-09-30  Female      Service
# 1      fffe3700360033003500      2008-11-30    Male      Service
# 2  fffe31003300320037003900      2008-03-10  Female      Product
# 3  fffe32003400380032003900      2008-11-03    Male      Service
# 4  fffe31003900340031003600      2008-07-24  Female      Service
#
#   WFH Setup Available  Designation  Resource Allocation  Mental Fatigue Score  \
# 0                  No            2                  3.0                   3.8
# 1                 Yes            1                  2.0                   5.0
# 2                 Yes            2                  NaN                   5.8
# 3                 Yes            1                  1.0                   2.6
# 4                  No            3                  7.0                   6.9
#
#    Happiness  HappyCond       today
# 0       0.84          1  2021-12-09
# 1       0.64          1  2021-12-09
# 2       0.51          1  2021-12-09
# 3       0.80          1  2021-12-09
# 4       0.48          0  2021-12-09

# %%
data_train["today"] =  pd.to_datetime(data_train["today"])
data_test["today"] =  pd.to_datetime(data_test["today"])

# %%
data_train['tenure'] = data_train['today'] - data_train["Date of Joining"]
data_test['tenure'] = data_test['today'] - data_test["Date of Joining"]
data_train.head()
# Out:
#                 Employee ID Date of Joining  Gender Company Type  \
# 0  fffe32003000360033003200      2008-09-30  Female      Service
# 1      fffe3700360033003500      2008-11-30    Male      Service
# 2  fffe31003300320037003900      2008-03-10  Female      Product
# 3  fffe32003400380032003900      2008-11-03    Male      Service
# 4  fffe31003900340031003600      2008-07-24  Female      Service
#
#   WFH Setup Available  Designation  Resource Allocation  Mental Fatigue Score  \
# 0                  No            2                  3.0                   3.8
# 1                 Yes            1                  2.0                   5.0
# 2                 Yes            2                  NaN                   5.8
# 3                 Yes            1                  1.0                   2.6
# 4                  No            3                  7.0                   6.9
#
#    Happiness  HappyCond      today    tenure
# 0       0.84          1 2021-12-09 4818 days
# 1       0.64          1 2021-12-09 4757 days
# 2       0.51          1 2021-12-09 5022 days
# 3       0.80          1 2021-12-09 4784 days
# 4       0.48          0 2021-12-09 4886 days

# %%
data_train.dtypes
# Out:
# Employee ID                      object
# Date of Joining          datetime64[ns]
# Gender                           object
# Company Type                     object
# WFH Setup Available              object
# Designation                       int64
# Resource Allocation             float64
# Mental Fatigue Score            float64
# Happiness                       float64
# HappyCond                         int64
# today                    datetime64[ns]
# tenure                  timedelta64[ns]
# dtype: object

# %%
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

data_train['tenure'] = data_train['tenure'].astype(int)
data_test['tenure'] = data_test['tenure'].astype(int)
data_train.dtypes
# Out:
# Employee ID                     object
# Date of Joining         datetime64[ns]
# Gender                          object
# Company Type                    object
# WFH Setup Available             object
# Designation                      int64
# Resource Allocation            float64
# Mental Fatigue Score           float64
# Happiness                      float64
# HappyCond                        int64
# today                   datetime64[ns]
# tenure                           int64
# dtype: object

# %%
data_test.dtypes
# Out:
# Employee ID                     object
# Date of Joining         datetime64[ns]
# Gender                          object
# Company Type                    object
# WFH Setup Available             object
# Designation                      int64
# Resource Allocation              int64
# Mental Fatigue Score           float64
# today                   datetime64[ns]
# tenure                           int64
# dtype: object

# %%
data_train = data_train.drop(["Employee ID", "Date of Joining", "today"], axis=1)
data_test = data_test.drop(["Employee ID", "Date of Joining", "today"], axis=1)
print(data_train.info())
print(data_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22750 entries, 0 to 22749
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                22750 non-null  object
#  1   Company Type          22750 non-null  object
#  2   WFH Setup Available   22750 non-null  object
#  3   Designation           22750 non-null  int64
#  4   Resource Allocation   21369 non-null  float64
#  5   Mental Fatigue Score  20633 non-null  float64
#  6   Happiness             21626 non-null  float64
#  7   HappyCond             22750 non-null  int64
#  8   tenure                22750 non-null  int64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 1.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12250 entries, 0 to 12249
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                12250 non-null  object
#  1   Company Type          12250 non-null  object
#  2   WFH Setup Available   12250 non-null  object
#  3   Designation           12250 non-null  int64
#  4   Resource Allocation   12250 non-null  int64
#  5   Mental Fatigue Score  12250 non-null  float64
#  6   tenure                12250 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 670.0+ KB
# None

# %%
# Drop rows where target variable "Happiness" is missing.
data_train = data_train.dropna(subset=['Happiness'])
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21626 entries, 0 to 22749
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                21626 non-null  object
#  1   Company Type          21626 non-null  object
#  2   WFH Setup Available   21626 non-null  object
#  3   Designation           21626 non-null  int64
#  4   Resource Allocation   20348 non-null  float64
#  5   Mental Fatigue Score  19681 non-null  float64
#  6   Happiness             21626 non-null  float64
#  7   HappyCond             21626 non-null  int64
#  8   tenure                21626 non-null  int64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 1.6+ MB

# %%
# Impute remaining missing values with medians
df_train = data_train
for col in ['Resource Allocation', 'Mental Fatigue Score']:
    df_train[col] = df_train[col].fillna(df_train[col].median())

df_train.info()
df_train.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21626 entries, 0 to 22749
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                21626 non-null  object
#  1   Company Type          21626 non-null  object
#  2   WFH Setup Available   21626 non-null  object
#  3   Designation           21626 non-null  int64
#  4   Resource Allocation   21626 non-null  float64
#  5   Mental Fatigue Score  21626 non-null  float64
#  6   Happiness             21626 non-null  float64
#  7   HappyCond             21626 non-null  int64
#  8   tenure                21626 non-null  int64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 1.6+ MB
#         Designation  Resource Allocation  Mental Fatigue Score     Happiness  \
# count  21626.000000         21626.000000          21626.000000  21626.000000
# mean       2.178766             4.455239              5.745154      0.547995
# std        1.135428             1.990000              1.833016      0.198226
# min        0.000000             1.000000              0.000000      0.000000
# 25%        1.000000             3.000000              4.700000      0.410000
# 50%        2.000000             4.000000              5.900000      0.550000
# 75%        3.000000             6.000000              6.900000      0.690000
# max        5.000000            10.000000             10.000000      1.000000
#
#           HappyCond        tenure
# count  21626.000000  2.162600e+04
# mean       0.602331  4.241064e+17
# std        0.489428  9.105099e+15
# min        0.000000  4.083264e+17
# 25%        0.000000  4.162752e+17
# 50%        1.000000  4.240512e+17
# 75%        1.000000  4.320864e+17
# max        1.000000  4.398624e+17

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
#%matplotlib inline
sns.set(color_codes=True)

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(10,5))
sns.countplot(df_train["Gender"], palette="winter", ax=ax[0])
sns.countplot(df_train["Company Type"], palette="winter", ax=ax[1])
sns.countplot(df_train["WFH Setup Available"], palette="winter", ax=ax[2])
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(14,5))
sns.boxenplot(x="Gender", y="Happiness", hue="Company Type", data=df_train, palette="winter", linewidth=0.0, ax=ax[0])
sns.boxenplot(x="Gender", y="Happiness", hue="WFH Setup Available", data=df_train, palette="winter", linewidth=0.0, ax=ax[1])
sns.boxenplot(x="WFH Setup Available", y="Happiness", hue="Company Type", data=df_train, palette="winter", linewidth=0.0, ax=ax[2])
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(14,5))
sns.barplot(x="Gender", y="HappyCond", hue="Company Type", data=df_train, palette="winter", linewidth=0.0, ax=ax[0])
sns.barplot(x="Gender", y="HappyCond", hue="WFH Setup Available", data=df_train, palette="winter", linewidth=0.0, ax=ax[1])
sns.barplot(x="WFH Setup Available", y="HappyCond", hue="Company Type", data=df_train, palette="winter", linewidth=0.0, ax=ax[2])
plt.tight_layout()
plt.show()

# %%
cont = ["Happiness", "Resource Allocation", "Mental Fatigue Score", "tenure"]
df_cont = df_train[cont]

# %%
k = 4
fig = plt.figure(figsize=(14,5))
# Correlations between each variable
corrmat = df_cont.corr()
# Take k elements in descending order of coefficient
cols = corrmat.nlargest(k, "Happiness")["Happiness"].index

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(14,5))
sns.scatterplot(x="Mental Fatigue Score", y="Happiness", hue="Gender", data=df_train, linewidth=0.0, ax=ax[0])
sns.scatterplot(x="Resource Allocation", y="Happiness", hue="Gender", data=df_train, linewidth=0.0, ax=ax[1])
sns.scatterplot(x="tenure", y="Happiness", hue="Gender", data=df_train, linewidth=0.0, ax=ax[2])
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(14,5))
sns.scatterplot(x="Mental Fatigue Score", y="Happiness", hue="WFH Setup Available", data=df_train, linewidth=0.0, ax=ax[0])
sns.scatterplot(x="Resource Allocation", y="Happiness", hue="WFH Setup Available", data=df_train, linewidth=0.0, ax=ax[1])
sns.scatterplot(x="tenure", y="Happiness", hue="WFH Setup Available", data=df_train, linewidth=0.0, ax=ax[2])
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(10,5))
sns.boxenplot(x="Gender", y="Mental Fatigue Score", data=df_train, palette="winter", linewidth=0.0, ax=ax[0])
sns.boxenplot(x="Company Type", y="Mental Fatigue Score", data=df_train, palette="winter", linewidth=0.0, ax=ax[1])
sns.boxenplot(x="WFH Setup Available", y="Mental Fatigue Score", data=df_train, palette="winter", linewidth=0.0, ax=ax[2])
plt.tight_layout()
plt.show()

# %%
list_cols = ['Gender','Company Type','WFH Setup Available']

ce_ohe = ce.OneHotEncoder(cols=list_cols)
df_train = ce_ohe.fit_transform(df_train)
df_train.head()

ce_ohe2 = ce.OneHotEncoder(cols=list_cols)
data_test = ce_ohe2.fit_transform(data_test)

# %%
X = df_train.drop(['Happiness','Gender_2','Company Type_2','WFH Setup Available_2','HappyCond'], axis=1)
y = df_train['HappyCond']

# %%
data_test = data_test.drop(['Gender_2','Company Type_2','WFH Setup Available_2'], axis=1)

# %%
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split

# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7,test_size = 0.3, random_state=100)

# %%
cols = X.columns
X_test.dtypes
# Out:
# Gender_1                   int64
# Company Type_1             int64
# WFH Setup Available_1      int64
# Designation                int64
# Resource Allocation      float64
# Mental Fatigue Score     float64
# tenure                     int64
# dtype: object

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform (X_test)

# %%
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)

# %%
X_train.columns = cols
X_test.columns = cols

# %%
# train a Gaussian Naive Bayes classifier on the training set
from sklearn.naive_bayes import GaussianNB

# instantiate the model
gnb = GaussianNB()

# fit the model
gnb.fit(X_train, y_train)
y_pred= gnb.predict(X_test)
gnb_pred=gnb.predict_proba(X_test)
gnb_pred
# Out:
# array([[9.99855015e-01, 1.44985038e-04],
#        [7.06214513e-06, 9.99992938e-01],
#        [9.97561101e-01, 2.43889929e-03],
#        ...,
#        [1.50725953e-02, 9.84927405e-01],
#        [9.99822321e-01, 1.77679072e-04],
#        [9.81248972e-01, 1.87510282e-02]])

# %%
from sklearn.metrics import accuracy_score

print('Model accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score: 0.9012

# %%
df = pd.DataFrame(gnb_pred)
df
# Out:
#              0         1
# 0     0.999855  0.000145
# 1     0.000007  0.999993
# 2     0.997561  0.002439
# 3     0.997644  0.002356
# 4     0.938693  0.061307
# ...        ...       ...
# 6483  0.943239  0.056761
# 6484  0.420531  0.579469
# 6485  0.015073  0.984927
# 6486  0.999822  0.000178
# 6487  0.981249  0.018751
#
# [6488 rows x 2 columns]

# %%
c = 0
happinessLevel = {}
for index, row in df.iterrows():
    if row[0]> row[1]:
        happinessLevel[index]= "Unhappy"
    else:
        happinessLevel[index]= "Happy"
        c +=1
        
    print("Employee ID - " +test_EmpId[index]+" - " + happinessLevel[index])
print (c)
# Out:
# Employee ID - fffe31003300390039003000 - Unhappy
# Employee ID - fffe31003300310037003800 - Happy
# Employee ID - fffe33003400380035003900 - Unhappy
# Employee ID - fffe3100370039003200 - Unhappy
# Employee ID - fffe32003600390036003700 - Unhappy
# Employee ID - fffe3600390032003200 - Happy
# Employee ID - fffe3600370032003200 - Happy
# Employee ID - fffe32003900390030003000 - Happy
# Employee ID - fffe3100370031003000 - Happy
# Employee ID - fffe31003500320037003600 - Unhappy
# Employee ID - fffe3400370031003100 - Happy
# Employee ID - fffe32003800300035003300 - Happy
# Employee ID - fffe31003700380037003700 - Happy
# Employee ID - fffe33003400300038003900 - Unhappy
# Employee ID - fffe33003100300039003600 - Happy
# Employee ID - fffe33003400380038003300 - Unhappy
# Employee ID - fffe33003400310032003500 - Happy
# Employee ID - fffe33003400360032003000 - Unhappy
# Employee ID - fffe32003800360033003400 - Unhappy
# Employee ID - fffe3600350031003700 - Unhappy
# Employee ID - fffe3200310033003500 - Unhappy
# Employee ID - fffe370039003500 - Unhappy
# Employee ID - fffe32003500340036003200 - Happy
# Employee ID - fffe360038003200 - Happy
# Employee ID - fffe31003800300039003900 - Unhappy
# Employee ID - fffe32003500310034003200 - Unhappy
# Employee ID - fffe33003100320039003300 - Happy
# Employee ID - fffe33003000330034003700 - Happy
# Employee ID - fffe32003500310039003300 - Unhappy
# Employee ID - fffe31003500310033003200 - Unhappy
# Employee ID - fffe31003900320038003800 - Unhappy
# Employee ID - fffe31003400340039003000 - Happy
# Employee ID - fffe390033003000 - Unhappy
# Employee ID - fffe3700360033003400 - Happy
# Employee ID - fffe31003700390034003900 - Happy
# Employee ID - fffe31003700360035003900 - Happy
# Employee ID - fffe31003200370037003900 - Unhappy
# Employee ID - fffe31003400310038003500 - Unhappy
# Employee ID - fffe32003200370033003000 - Happy
# Employee ID - fffe31003300320036003300 - Happy
# Employee ID - fffe3900390034003600 - Happy
# Employee ID - fffe32003300310032003600 - Unhappy
# Employee ID - fffe3500360039003300 - Happy
# Employee ID - fffe3700340039003900 - Unhappy
# Employee ID - fffe31003400370032003200 - Happy
# Employee ID - fffe360032003200 - Happy
# Employee ID - fffe33003100340030003600 - Happy
# Employee ID - fffe31003500300037003700 - Happy
# Employee ID - fffe31003600390038003800 - Unhappy
# Employee ID - fffe33003300360030003500 - Happy
# Employee ID - fffe3900380030003300 - Unhappy
# Employee ID - fffe31003700330034003500 - Unhappy
# Employee ID - fffe31003500360036003900 - Happy
# Employee ID - fffe3200380033003100 - Happy
# Employee ID - fffe3900360033003900 - Happy
# Employee ID - fffe33003000370031003200 - Happy
# Employee ID - fffe32003700370036003200 - Happy
# Employee ID - fffe31003400320034003300 - Happy
# Employee ID - fffe32003600360034003200 - Unhappy
# Employee ID - fffe32003700380035003100 - Unhappy
# Employee ID - fffe31003400350034003200 - Happy
# Employee ID - fffe31003000320038003200 - Unhappy
# Employee ID - fffe32003400300030003800 - Unhappy
# Employee ID - fffe32003600320038003300 - Happy
# Employee ID - fffe3300340035003700 - Unhappy
# Employee ID - fffe31003900320032003000 - Unhappy
# Employee ID - fffe3300370032003100 - Happy
# Employee ID - fffe33003300350038003900 - Unhappy
# Employee ID - fffe32003900360038003700 - Happy
# Employee ID - fffe3100380033003400 - Happy
# Employee ID - fffe3900390032003500 - Unhappy
# Employee ID - fffe32003200320035003600 - Happy
# Employee ID - fffe32003700380031003900 - Happy
# Employee ID - fffe3400330034003000 - Happy
# Employee ID - fffe33003300380035003400 - Unhappy
# Employee ID - fffe3300380034003000 - Happy
# Employee ID - fffe32003500360039003200 - Happy
# Employee ID - fffe31003700360038003600 - Unhappy
# Employee ID - fffe33003300370036003200 - Unhappy
# Employee ID - fffe3200340039003500 - Happy
# Employee ID - fffe3600300036003500 - Happy
# Employee ID - fffe31003300370032003000 - Happy
# Employee ID - fffe3700360036003700 - Happy
# Employee ID - fffe33003200390030003200 - Happy
# Employee ID - fffe31003500340035003100 - Happy
# Employee ID - fffe33003000350035003300 - Unhappy
# Employee ID - fffe31003400300036003000 - Unhappy
# Employee ID - fffe31003700330035003200 - Unhappy
# Employee ID - fffe33003000320032003400 - Happy
# Employee ID - fffe32003300350034003700 - Unhappy
# Employee ID - fffe32003200340034003400 - Happy
# Employee ID - fffe3800380035003100 - Happy
# Employee ID - fffe33003100310039003900 - Happy
# Employee ID - fffe3700330032003300 - Happy
# Employee ID - fffe32003300390033003900 - Happy
# Employee ID - fffe31003500370037003700 - Happy
# Employee ID - fffe32003000310035003500 - Happy
# Employee ID - fffe38003200 - Happy
# Employee ID - fffe31003900310032003600 - Happy
# Employee ID - fffe32003200320039003900 - Happy
# Employee ID - fffe33003000360035003200 - Unhappy
# Employee ID - fffe33003100390031003800 - Happy
# Employee ID - fffe32003800360031003400 - Unhappy
# Employee ID - fffe32003300320034003300 - Unhappy
# Employee ID - fffe3800330032003400 - Unhappy
# Employee ID - fffe3600380038003000 - Happy
# Employee ID - fffe32003500320030003700 - Unhappy
# Employee ID - fffe33003400330032003600 - Happy
# Employee ID - fffe32003300380030003600 - Happy
# Employee ID - fffe31003000360032003900 - Happy
# Employee ID - fffe3300310032003500 - Happy
# Employee ID - fffe3200320033003000 - Happy
# Employee ID - fffe340032003600 - Happy
# Employee ID - fffe3900390036003500 - Unhappy
# Employee ID - fffe3900310039003900 - Unhappy
# Employee ID - fffe3700390037003100 - Unhappy
# Employee ID - fffe31003200340031003600 - Happy
# Employee ID - fffe33003200380038003800 - Happy
# Employee ID - fffe32003400380038003200 - Happy
# Employee ID - fffe32003300330037003600 - Happy
# Employee ID - fffe33003400360030003700 - Unhappy
# Employee ID - fffe31003900340030003800 - Unhappy
# Employee ID - fffe33003400300037003400 - Unhappy
# Employee ID - fffe3400360035003700 - Unhappy
# Employee ID - fffe33003000340039003100 - Unhappy
# Employee ID - fffe32003000390030003300 - Happy
# Employee ID - fffe32003800300030003000 - Unhappy
# Employee ID - fffe32003500300032003800 - Happy
# Employee ID - fffe3800330032003700 - Happy
# Employee ID - fffe32003900380039003600 - Happy
# Employee ID - fffe3200310031003300 - Happy
# Employee ID - fffe32003700350038003000 - Unhappy
# Employee ID - fffe31003800370033003700 - Unhappy
# Employee ID - fffe33003300380038003100 - Unhappy
# Employee ID - fffe31003400340030003400 - Happy
# Employee ID - fffe31003000340030003400 - Happy
# Employee ID - fffe31003400330032003700 - Unhappy
# Employee ID - fffe31003700310030003300 - Unhappy
# Employee ID - fffe31003300310033003300 - Happy
# Employee ID - fffe33003400330031003500 - Unhappy
# Employee ID - fffe32003800300036003800 - Happy
# Employee ID - fffe33003000300032003900 - Happy
# Employee ID - fffe32003800390035003700 - Unhappy
# Employee ID - fffe3400320036003200 - Happy
# Employee ID - fffe33003200390038003700 - Happy
# Employee ID - fffe33003100380035003700 - Unhappy
# Employee ID - fffe32003900350032003100 - Unhappy
# Employee ID - fffe31003400360032003800 - Unhappy
# Employee ID - fffe32003500340030003200 - Unhappy
# Employee ID - fffe32003600330035003300 - Unhappy
# Employee ID - fffe3700320033003600 - Happy
# Employee ID - fffe31003400310033003000 - Happy
# Employee ID - fffe31003400380034003800 - Happy
# Employee ID - fffe32003300340039003700 - Happy
# Employee ID - fffe31003300360031003300 - Happy
# Employee ID - fffe3500350037003800 - Happy
# Employee ID - fffe32003300350035003400 - Unhappy
# Employee ID - fffe3600310037003400 - Happy
# Employee ID - fffe3200350036003400 - Unhappy
# Employee ID - fffe33003100350034003600 - Unhappy
# Employee ID - fffe3700390038003600 - Happy
# Employee ID - fffe31003200350033003800 - Happy
# Employee ID - fffe32003300320033003400 - Unhappy
# Employee ID - fffe31003900360035003900 - Happy
# Employee ID - fffe3400360036003800 - Unhappy
# Employee ID - fffe3100320032003000 - Unhappy
# Employee ID - fffe3900310038003900 - Happy
# Employee ID - fffe3500330032003600 - Happy
# Employee ID - fffe3700370034003000 - Unhappy
# Employee ID - fffe3100310038003800 - Happy
# Employee ID - fffe33003300350036003500 - Happy
# Employee ID - fffe33003400390031003600 - Happy
# Employee ID - fffe31003400370035003400 - Happy
# Employee ID - fffe31003600340039003900 - Happy
# Employee ID - fffe31003600350034003300 - Unhappy
# Employee ID - fffe32003900310033003300 - Happy
# Employee ID - fffe32003700300039003800 - Happy
# Employee ID - fffe32003600340036003300 - Unhappy
# Employee ID - fffe31003100340039003600 - Unhappy
# Employee ID - fffe31003700340036003000 - Unhappy
# Employee ID - fffe31003600390030003700 - Unhappy
# Employee ID - fffe32003500320036003900 - Happy
# Employee ID - fffe32003200330033003700 - Happy
# Employee ID - fffe32003500380035003600 - Happy
# Employee ID - fffe32003900330030003800 - Unhappy
# Employee ID - fffe3700360031003700 - Happy
# Employee ID - fffe31003400350032003300 - Happy
# Employee ID - fffe31003000300034003900 - Happy
# Employee ID - fffe31003500370032003200 - Happy
# Employee ID - fffe31003400330039003100 - Happy
# Employee ID - fffe33003100340037003400 - Happy
# Employee ID - fffe33003300390033003500 - Happy
# Employee ID - fffe390035003800 - Happy
# Employee ID - fffe31003500310033003600 - Happy
# Employee ID - fffe31003600390032003600 - Unhappy
# Employee ID - fffe31003600300038003000 - Unhappy
# Employee ID - fffe3800390036003400 - Happy
# Employee ID - fffe33003100380031003200 - Happy
# Employee ID - fffe33003100390033003000 - Happy
# Employee ID - fffe31003100370034003800 - Happy
# Employee ID - fffe32003500370034003400 - Happy
# Employee ID - fffe350039003100 - Unhappy
# Employee ID - fffe31003000340030003500 - Happy
# Employee ID - fffe33003300340034003300 - Unhappy
# Employee ID - fffe31003600330032003500 - Happy
# Employee ID - fffe31003400350037003900 - Happy
# Employee ID - fffe31003800370035003000 - Unhappy
# Employee ID - fffe3400320037003600 - Happy
# Employee ID - fffe33003100390034003000 - Happy
# Employee ID - fffe31003000340037003600 - Happy
# Employee ID - fffe3800380033003600 - Unhappy
# Employee ID - fffe33003300380030003100 - Unhappy
# Employee ID - fffe3900370035003800 - Unhappy
# Employee ID - fffe3800370031003400 - Happy
# Employee ID - fffe3600380039003100 - Happy
# Employee ID - fffe3100300039003200 - Happy
# Employee ID - fffe31003000330034003700 - Unhappy
# Employee ID - fffe33003400390034003000 - Unhappy
# Employee ID - fffe32003600360035003500 - Happy
# Employee ID - fffe3900380031003100 - Unhappy
# Employee ID - fffe3200350035003000 - Happy
# Employee ID - fffe32003400310032003000 - Happy
# Employee ID - fffe33003200340033003300 - Happy
# Employee ID - fffe3800340035003200 - Happy
# Employee ID - fffe32003300360035003400 - Unhappy
# Employee ID - fffe3200380031003700 - Happy
# Employee ID - fffe31003200360035003900 - Happy
# Employee ID - fffe33003200320036003800 - Happy
# Employee ID - fffe31003500320035003500 - Happy
# Employee ID - fffe31003400330039003500 - Unhappy
# Employee ID - fffe32003600360038003200 - Happy
# Employee ID - fffe33003000 - Unhappy
# Employee ID - fffe33003300370036003900 - Unhappy
# Employee ID - fffe31003200310031003600 - Happy
# Employee ID - fffe33003400320035003000 - Happy
# Employee ID - fffe33003100300036003800 - Happy
# Employee ID - fffe3200370037003800 - Unhappy
# Employee ID - fffe32003500300036003500 - Unhappy
# Employee ID - fffe32003800380034003300 - Happy
# Employee ID - fffe33003100350032003000 - Happy
# Employee ID - fffe31003300340031003000 - Happy
# Employee ID - fffe32003100390031003500 - Unhappy
# Employee ID - fffe3100380034003300 - Happy
# Employee ID - fffe31003100320030003300 - Happy
# Employee ID - fffe31003200350035003800 - Happy
# Employee ID - fffe31003200350034003500 - Unhappy
# Employee ID - fffe32003500380037003700 - Happy
# Employee ID - fffe32003500320031003100 - Happy
# Employee ID - fffe3700310035003300 - Happy
# Employee ID - fffe31003300390035003400 - Unhappy
# Employee ID - fffe31003400390037003000 - Happy
# Employee ID - fffe32003600300037003100 - Unhappy
# Employee ID - fffe3900380038003700 - Happy
# Employee ID - fffe3600390031003300 - Unhappy
# Employee ID - fffe33003100390031003100 - Happy
# Employee ID - fffe3100320036003300 - Happy
# Employee ID - fffe3900350030003300 - Unhappy
# Employee ID - fffe32003300350036003100 - Happy
# Employee ID - fffe33003200360032003400 - Happy
# Employee ID - fffe31003400320038003000 - Unhappy
# Employee ID - fffe31003300310033003900 - Happy
# Employee ID - fffe3800300034003300 - Unhappy
# Employee ID - fffe32003200370031003200 - Happy
# Employee ID - fffe31003400340039003200 - Unhappy
# Employee ID - fffe32003600340039003600 - Unhappy
# Employee ID - fffe33003100370036003600 - Unhappy
# Employee ID - fffe32003600320031003600 - Unhappy
# Employee ID - fffe32003000380030003700 - Happy
# Employee ID - fffe32003700340034003800 - Unhappy
# Employee ID - fffe32003100350030003100 - Unhappy
# Employee ID - fffe32003400380031003200 - Happy
# Employee ID - fffe31003300370030003800 - Unhappy
# Employee ID - fffe32003500360031003400 - Happy
# Employee ID - fffe3600370037003500 - Happy
# Employee ID - fffe32003300380034003100 - Happy
# Employee ID - fffe32003800310031003300 - Happy
# Employee ID - fffe31003700330031003300 - Happy
# Employee ID - fffe32003000300036003900 - Happy
# Employee ID - fffe31003200370032003100 - Happy
# Employee ID - fffe3500340039003400 - Unhappy
# Employee ID - fffe32003400330037003400 - Happy
# Employee ID - fffe31003000340039003900 - Unhappy
# Employee ID - fffe31003600350038003800 - Happy
# Employee ID - fffe3400320039003600 - Unhappy
# Employee ID - fffe3800310034003200 - Happy
# Employee ID - fffe31003500340033003600 - Unhappy
# Employee ID - fffe3700340036003200 - Unhappy
# Employee ID - fffe32003800340036003200 - Happy
# Employee ID - fffe3700390035003900 - Happy
# Employee ID - fffe32003500300039003100 - Unhappy
# Employee ID - fffe31003800340039003900 - Happy
# Employee ID - fffe32003200360032003300 - Unhappy
# Employee ID - fffe3900370038003200 - Unhappy
# Employee ID - fffe3400300031003000 - Unhappy
# Employee ID - fffe31003700390036003500 - Happy
# Employee ID - fffe32003000390035003900 - Unhappy
# Employee ID - fffe32003400330038003700 - Happy
# Employee ID - fffe32003100300037003100 - Happy
# Employee ID - fffe32003700390038003300 - Happy
# Employee ID - fffe31003400380034003400 - Unhappy
# Employee ID - fffe31003500310036003100 - Happy
# Employee ID - fffe31003200360032003300 - Unhappy
# Employee ID - fffe33003400350032003300 - Happy
# Employee ID - fffe32003300300035003300 - Unhappy
# Employee ID - fffe33003200380031003700 - Happy
# Employee ID - fffe3700360039003000 - Happy
# Employee ID - fffe33003300310035003000 - Happy
# Employee ID - fffe31003500390036003900 - Happy
# Employee ID - fffe380037003500 - Happy
# Employee ID - fffe31003200330033003100 - Happy
# Employee ID - fffe31003200320032003700 - Unhappy
# Employee ID - fffe33003000380031003700 - Happy
# Employee ID - fffe32003400320032003300 - Unhappy
# Employee ID - fffe33003000340035003500 - Unhappy
# Employee ID - fffe31003800320033003300 - Unhappy
# Employee ID - fffe3600390031003800 - Unhappy
# Employee ID - fffe33003300370036003700 - Happy
# Employee ID - fffe31003600390032003000 - Happy
# Employee ID - fffe32003000350038003100 - Happy
# Employee ID - fffe31003500330033003400 - Happy
# Employee ID - fffe32003000380032003800 - Unhappy
# Employee ID - fffe31003400350032003000 - Happy
# Employee ID - fffe31003300300037003700 - Happy
# Employee ID - fffe310032003900 - Happy
# Employee ID - fffe33003200380036003500 - Unhappy
# Employee ID - fffe3900340033003300 - Happy
# Employee ID - fffe33003000380036003000 - Happy
# Employee ID - fffe31003500300038003400 - Happy
# Employee ID - fffe3500350036003500 - Happy
# Employee ID - fffe3600350033003500 - Unhappy
# Employee ID - fffe33003200300037003100 - Happy
# Employee ID - fffe3300310032003000 - Happy
# Employee ID - fffe32003100300034003800 - Happy
# Employee ID - fffe3300320038003500 - Happy
# Employee ID - fffe32003000330035003400 - Unhappy
# Employee ID - fffe3800330036003800 - Happy
# Employee ID - fffe3600360030003200 - Unhappy
# Employee ID - fffe3500380036003000 - Happy
# Employee ID - fffe31003200380036003500 - Unhappy
# Employee ID - fffe3200380038003300 - Unhappy
# Employee ID - fffe33003400390031003100 - Happy
# Employee ID - fffe3700320039003400 - Unhappy
# Employee ID - fffe31003600380030003100 - Happy
# Employee ID - fffe3900300035003800 - Happy
# Employee ID - fffe31003300360036003900 - Unhappy
# Employee ID - fffe31003100360032003200 - Unhappy
# Employee ID - fffe31003500340031003600 - Happy
# Employee ID - fffe31003000300034003700 - Happy
# Employee ID - fffe3600380032003700 - Happy
# Employee ID - fffe32003800310037003800 - Unhappy
# Employee ID - fffe31003600370034003600 - Happy
# Employee ID - fffe32003400320038003600 - Happy
# Employee ID - fffe32003300340036003200 - Happy
# Employee ID - fffe3500300038003900 - Happy
# Employee ID - fffe31003500360036003000 - Unhappy
# Employee ID - fffe31003000390036003800 - Happy
# Employee ID - fffe3900320031003600 - Happy
# Employee ID - fffe33003300360035003400 - Happy
# Employee ID - fffe31003100370038003700 - Unhappy
# Employee ID - fffe33003300320034003500 - Unhappy
# Employee ID - fffe3300370033003700 - Happy
# Employee ID - fffe32003000320030003100 - Unhappy
# Employee ID - fffe32003400320036003000 - Unhappy
# Employee ID - fffe33003200330037003600 - Happy
# Employee ID - fffe31003900380031003100 - Happy
# Employee ID - fffe3700350035003200 - Unhappy
# Employee ID - fffe32003100310030003200 - Unhappy
# Employee ID - fffe31003100370031003400 - Happy
# Employee ID - fffe31003800370030003700 - Unhappy
# Employee ID - fffe3700370034003600 - Happy
# Employee ID - fffe3900370039003400 - Happy
# Employee ID - fffe32003500330035003600 - Happy
# Employee ID - fffe31003300360031003900 - Happy
# Employee ID - fffe32003300380034003800 - Unhappy
# Employee ID - fffe31003800390035003000 - Unhappy
# Employee ID - fffe31003100300039003300 - Happy
# Employee ID - fffe32003100350033003200 - Happy
# Employee ID - fffe3200360034003100 - Happy
# Employee ID - fffe32003200340033003800 - Unhappy
# Employee ID - fffe32003600360030003100 - Unhappy
# Employee ID - fffe31003600340033003500 - Happy
# Employee ID - fffe3200330030003800 - Happy
# Employee ID - fffe32003900370035003300 - Happy
# Employee ID - fffe31003500380031003300 - Unhappy
# Employee ID - fffe31003600360038003400 - Happy
# Employee ID - fffe3400380034003800 - Happy
# Employee ID - fffe33003100380039003200 - Happy
# Employee ID - fffe31003100330034003200 - Happy
# Employee ID - fffe31003600340030003800 - Happy
# Employee ID - fffe3100380035003900 - Happy
# Employee ID - fffe32003900380039003500 - Unhappy
# Employee ID - fffe31003700300030003800 - Happy
# Employee ID - fffe31003800370031003800 - Unhappy
# Employee ID - fffe3200330033003600 - Happy
# Employee ID - fffe3700360038003700 - Happy
# Employee ID - fffe3300320031003700 - Happy
# Employee ID - fffe31003100360030003200 - Happy
# Employee ID - fffe31003300360036003800 - Unhappy
# Employee ID - fffe32003100390033003800 - Unhappy
# Employee ID - fffe31003900350039003000 - Happy
# Employee ID - fffe32003200320033003300 - Happy
# Employee ID - fffe32003800340035003300 - Happy
# Employee ID - fffe31003100330032003800 - Happy
# Employee ID - fffe3400350039003900 - Unhappy
# Employee ID - fffe3800310036003000 - Happy
# Employee ID - fffe31003600320033003600 - Happy
# Employee ID - fffe32003400370039003500 - Unhappy
# Employee ID - fffe3700300036003800 - Unhappy
# Employee ID - fffe33003000300033003200 - Happy
# Employee ID - fffe33003000370037003100 - Unhappy
# Employee ID - fffe31003100320038003100 - Happy
# Employee ID - fffe32003500370035003700 - Unhappy
# Employee ID - fffe31003100320038003500 - Happy
# Employee ID - fffe32003600300035003500 - Happy
# Employee ID - fffe32003600300034003900 - Unhappy
# Employee ID - fffe3300320039003400 - Unhappy
# Employee ID - fffe32003800390033003300 - Happy
# Employee ID - fffe31003600340035003800 - Happy
# Employee ID - fffe32003000390030003700 - Unhappy
# Employee ID - fffe31003300320038003100 - Happy
# Employee ID - fffe31003600370030003700 - Unhappy
# Employee ID - fffe32003000330039003400 - Unhappy
# Employee ID - fffe31003800340037003100 - Happy
# Employee ID - fffe31003500370038003900 - Unhappy
# Employee ID - fffe3500300037003700 - Unhappy
# Employee ID - fffe32003000320037003300 - Unhappy
# Employee ID - fffe31003900320036003700 - Happy
# Employee ID - fffe31003900350038003800 - Happy
# Employee ID - fffe31003800300034003200 - Happy
# Employee ID - fffe33003400350036003800 - Unhappy
# Employee ID - fffe31003400340034003400 - Happy
# Employee ID - fffe32003600320037003200 - Unhappy
# Employee ID - fffe3300390033003300 - Unhappy
# Employee ID - fffe32003200300031003300 - Unhappy
# Employee ID - fffe3100360036003100 - Happy
# Employee ID - fffe31003100320039003900 - Unhappy
# Employee ID - fffe32003700350031003400 - Happy
# Employee ID - fffe33003100360033003100 - Unhappy
# Employee ID - fffe3400310039003600 - Happy
# Employee ID - fffe32003300330036003400 - Unhappy
# Employee ID - fffe33003100320038003300 - Happy
# Employee ID - fffe32003200330034003600 - Unhappy
# Employee ID - fffe31003700350038003500 - Happy
# Employee ID - fffe32003100390030003900 - Happy
# Employee ID - fffe31003000330036003000 - Happy
# Employee ID - fffe390034003300 - Happy
# Employee ID - fffe3300310039003200 - Happy
# Employee ID - fffe31003700320030003600 - Happy
# Employee ID - fffe31003500330030003600 - Unhappy
# Employee ID - fffe32003300360039003200 - Happy
# Employee ID - fffe3500350031003400 - Unhappy
# Employee ID - fffe33003000390037003000 - Happy
# Employee ID - fffe3800340030003800 - Happy
# Employee ID - fffe3500390039003500 - Happy
# Employee ID - fffe32003100330033003100 - Unhappy
# Employee ID - fffe31003900380035003800 - Happy
# Employee ID - fffe31003200370033003400 - Happy
# Employee ID - fffe33003300340036003500 - Unhappy
# Employee ID - fffe3900380032003000 - Happy
# Employee ID - fffe32003700370035003500 - Happy
# Employee ID - fffe31003900330039003500 - Unhappy
# Employee ID - fffe32003400300036003900 - Unhappy
# Employee ID - fffe31003800320037003800 - Happy
# Employee ID - fffe3400360039003400 - Happy
# Employee ID - fffe32003700390036003000 - Unhappy
# Employee ID - fffe320032003600 - Unhappy
# Employee ID - fffe31003200300037003300 - Happy
# Employee ID - fffe3700380033003700 - Happy
# Employee ID - fffe330038003800 - Happy
# Employee ID - fffe33003200340038003100 - Unhappy
# Employee ID - fffe32003800370035003100 - Happy
# Employee ID - fffe3800300036003000 - Happy
# Employee ID - fffe32003200340039003800 - Happy
# Employee ID - fffe31003600320033003900 - Unhappy
# Employee ID - fffe3500340037003700 - Happy
# Employee ID - fffe32003500340039003100 - Happy
# Employee ID - fffe31003400380033003100 - Happy
# Employee ID - fffe3600370031003600 - Happy
# Employee ID - fffe32003600360035003000 - Happy
# Employee ID - fffe33003100380037003100 - Unhappy
# Employee ID - fffe32003900390035003100 - Happy
# Employee ID - fffe3800360039003300 - Happy
# Employee ID - fffe32003200310035003200 - Happy
# Employee ID - fffe31003200340036003300 - Happy
# Employee ID - fffe32003300340033003900 - Unhappy
# Employee ID - fffe32003800380033003500 - Unhappy
# Employee ID - fffe32003400380039003400 - Happy
# Employee ID - fffe3500350037003700 - Happy
# Employee ID - fffe32003700330037003800 - Unhappy
# Employee ID - fffe3700320030003800 - Unhappy
# Employee ID - fffe31003400350033003300 - Unhappy
# Employee ID - fffe380030003600 - Happy
# Employee ID - fffe31003300380038003400 - Unhappy
# Employee ID - fffe31003300330038003300 - Unhappy
# Employee ID - fffe33003200390039003800 - Happy
# Employee ID - fffe31003000340034003200 - Happy
# Employee ID - fffe3700310031003400 - Unhappy
# Employee ID - fffe32003500350032003100 - Unhappy
# Employee ID - fffe3100310037003400 - Unhappy
# Employee ID - fffe33003200360031003600 - Unhappy
# Employee ID - fffe31003900300038003300 - Unhappy
# Employee ID - fffe3400380039003900 - Unhappy
# Employee ID - fffe3500330036003500 - Happy
# Employee ID - fffe3800330035003100 - Happy
# Employee ID - fffe3100310032003200 - Happy
# Employee ID - fffe32003200340030003600 - Happy
# Employee ID - fffe33003300370038003900 - Happy
# Employee ID - fffe340035003600 - Unhappy
# Employee ID - fffe31003800370038003200 - Happy
# Employee ID - fffe3900330035003200 - Unhappy
# Employee ID - fffe31003700340039003300 - Happy
# Employee ID - fffe3100300034003300 - Happy
# Employee ID - fffe32003200380035003400 - Happy
# Employee ID - fffe3700300030003100 - Happy
# Employee ID - fffe3600370034003300 - Happy
# Employee ID - fffe31003700300037003700 - Unhappy
# Employee ID - fffe3900300032003200 - Happy
# Employee ID - fffe32003200340033003500 - Happy
# Employee ID - fffe31003500370034003300 - Unhappy
# Employee ID - fffe32003500350033003100 - Happy
# Employee ID - fffe33003300360033003600 - Happy
# Employee ID - fffe3900310038003000 - Happy
# Employee ID - fffe31003100390032003800 - Happy
# Employee ID - fffe32003900340038003500 - Unhappy
# Employee ID - fffe32003000300030003000 - Happy
# Employee ID - fffe31003600380037003000 - Happy
# Employee ID - fffe32003900330035003000 - Unhappy
# Employee ID - fffe3600310031003500 - Happy
# Employee ID - fffe3200380033003400 - Unhappy
# Employee ID - fffe32003800310030003700 - Unhappy
# Employee ID - fffe3900300032003300 - Happy
# Employee ID - fffe33003400350039003800 - Happy
# Employee ID - fffe31003600310033003100 - Happy
# Employee ID - fffe31003700320039003100 - Happy
# Employee ID - fffe3600360034003900 - Happy
# Employee ID - fffe31003800310031003000 - Unhappy
# Employee ID - fffe33003300320039003300 - Happy
# Employee ID - fffe3200380032003700 - Happy
# Employee ID - fffe3400390032003700 - Happy
# Employee ID - fffe32003900360031003000 - Happy
# Employee ID - fffe33003400360031003100 - Unhappy
# Employee ID - fffe32003700380033003200 - Happy
# Employee ID - fffe3500380030003100 - Happy
# Employee ID - fffe32003400370036003400 - Happy
# Employee ID - fffe33003100360033003700 - Unhappy
# Employee ID - fffe32003800380031003100 - Happy
# Employee ID - fffe3400310031003000 - Happy
# Employee ID - fffe31003800370030003500 - Unhappy
# Employee ID - fffe3700360036003800 - Unhappy
# Employee ID - fffe32003300310030003000 - Happy
# Employee ID - fffe32003300340036003900 - Happy
# Employee ID - fffe32003600310039003200 - Happy
# Employee ID - fffe3100380030003000 - Happy
# Employee ID - fffe3500310035003900 - Happy
# Employee ID - fffe33003400360030003800 - Unhappy
# Employee ID - fffe32003000300034003500 - Happy
# Employee ID - fffe32003600330037003000 - Unhappy
# Employee ID - fffe3900300034003600 - Happy
# Employee ID - fffe31003400380036003000 - Unhappy
# Employee ID - fffe31003400350031003000 - Unhappy
# Employee ID - fffe31003600360036003200 - Happy
# Employee ID - fffe32003100360035003900 - Happy
# Employee ID - fffe31003600340030003200 - Happy
# Employee ID - fffe31003200370037003600 - Unhappy
# Employee ID - fffe3200380039003300 - Happy
# Employee ID - fffe3800340030003700 - Happy
# Employee ID - fffe31003200310030003400 - Happy
# Employee ID - fffe330037003700 - Happy
# Employee ID - fffe31003600360035003500 - Unhappy
# Employee ID - fffe31003700320032003900 - Unhappy
# Employee ID - fffe31003400360033003300 - Unhappy
# Employee ID - fffe3800350031003600 - Unhappy
# Employee ID - fffe33003400380032003300 - Unhappy
# Employee ID - fffe33003100340038003100 - Happy
# Employee ID - fffe32003300340032003300 - Unhappy
# Employee ID - fffe32003400320035003300 - Happy
# Employee ID - fffe32003900340034003200 - Happy
# Employee ID - fffe32003600330036003200 - Happy
# Employee ID - fffe32003800340039003900 - Unhappy
# Employee ID - fffe32003800350037003600 - Unhappy
# Employee ID - fffe31003500330035003500 - Happy
# Employee ID - fffe3100380030003700 - Happy
# Employee ID - fffe31003200380031003800 - Unhappy
# Employee ID - fffe3600320034003100 - Happy
# Employee ID - fffe31003700310033003100 - Unhappy
# Employee ID - fffe31003800300037003600 - Happy
# Employee ID - fffe33003000380036003200 - Unhappy
# Employee ID - fffe31003200360036003000 - Happy
# Employee ID - fffe31003400340032003200 - Happy
# Employee ID - fffe3100380033003100 - Unhappy
# Employee ID - fffe32003300310032003400 - Unhappy
# Employee ID - fffe32003000330035003700 - Happy
# Employee ID - fffe31003800340038003100 - Happy
# Employee ID - fffe32003900350035003700 - Unhappy
# Employee ID - fffe31003300390039003700 - Unhappy
# Employee ID - fffe3600370036003200 - Unhappy
# Employee ID - fffe31003900380030003700 - Happy
# Employee ID - fffe3600390035003300 - Happy
# Employee ID - fffe3600370032003300 - Happy
# Employee ID - fffe310032003800 - Happy
# Employee ID - fffe32003800340031003100 - Unhappy
# Employee ID - fffe32003900330036003200 - Unhappy
# Employee ID - fffe33003100370033003200 - Happy
# Employee ID - fffe33003400370039003300 - Happy
# Employee ID - fffe32003300370031003300 - Unhappy
# Employee ID - fffe33003000330032003800 - Unhappy
# Employee ID - fffe31003900380032003100 - Happy
# Employee ID - fffe31003300340036003700 - Happy
# Employee ID - fffe3700360030003800 - Happy
# Employee ID - fffe32003800340031003000 - Happy
# Employee ID - fffe33003100300037003400 - Happy
# Employee ID - fffe32003400370036003900 - Unhappy
# Employee ID - fffe32003000330031003900 - Happy
# Employee ID - fffe32003900340038003600 - Happy
# Employee ID - fffe32003100320033003500 - Unhappy
# Employee ID - fffe3800340034003600 - Happy
# Employee ID - fffe33003300320035003700 - Unhappy
# Employee ID - fffe32003700350033003100 - Happy
# Employee ID - fffe31003100350038003500 - Happy
# Employee ID - fffe31003600310038003100 - Happy
# Employee ID - fffe31003800350039003300 - Unhappy
# Employee ID - fffe33003400320037003400 - Happy
# Employee ID - fffe31003100390030003500 - Unhappy
# Employee ID - fffe3500310033003500 - Happy
# Employee ID - fffe32003100380033003800 - Happy
# Employee ID - fffe33003100380039003700 - Unhappy
# Employee ID - fffe32003800300035003900 - Happy
# Employee ID - fffe3400340039003200 - Unhappy
# Employee ID - fffe32003100360032003300 - Happy
# Employee ID - fffe33003300360037003000 - Unhappy
# Employee ID - fffe32003600360033003400 - Happy
# Employee ID - fffe31003100300031003200 - Happy
# Employee ID - fffe3400390036003800 - Happy
# Employee ID - fffe33003200330030003900 - Happy
# Employee ID - fffe32003000380036003700 - Happy
# Employee ID - fffe3700310034003200 - Unhappy
# Employee ID - fffe32003500310034003000 - Happy
# Employee ID - fffe31003300380036003000 - Happy
# Employee ID - fffe32003100330033003300 - Unhappy
# Employee ID - fffe3700340036003100 - Happy
# Employee ID - fffe33003100350039003900 - Happy
# Employee ID - fffe32003300300034003900 - Happy
# Employee ID - fffe31003700320031003100 - Unhappy
# Employee ID - fffe32003400330031003500 - Happy
# Employee ID - fffe33003100320032003200 - Unhappy
# Employee ID - fffe33003000390038003600 - Happy
# Employee ID - fffe32003600370031003100 - Happy
# Employee ID - fffe3200340038003900 - Unhappy
# Employee ID - fffe31003600380038003300 - Unhappy
# Employee ID - fffe31003200350033003300 - Unhappy
# Employee ID - fffe3600370031003300 - Happy
# Employee ID - fffe33003100360031003800 - Unhappy
# Employee ID - fffe32003500370034003600 - Unhappy
# Employee ID - fffe33003000310032003400 - Happy
# Employee ID - fffe32003000370031003300 - Happy
# Employee ID - fffe31003300320032003200 - Happy
# Employee ID - fffe3200370038003600 - Unhappy
# Employee ID - fffe33003300380032003100 - Happy
# Employee ID - fffe31003300330038003600 - Unhappy
# Employee ID - fffe3900360037003000 - Unhappy
# Employee ID - fffe32003600360031003200 - Happy
# Employee ID - fffe33003300350038003100 - Happy
# Employee ID - fffe31003100330034003900 - Happy
# Employee ID - fffe3500340036003500 - Unhappy
# Employee ID - fffe32003500370030003700 - Happy
# Employee ID - fffe3400370033003800 - Happy
# Employee ID - fffe31003900300039003400 - Unhappy
# Employee ID - fffe31003300340034003600 - Happy
# Employee ID - fffe33003100380038003700 - Happy
# Employee ID - fffe31003900380034003400 - Unhappy
# Employee ID - fffe31003200320031003000 - Happy
# Employee ID - fffe3300380038003500 - Happy
# Employee ID - fffe31003500300038003500 - Happy
# Employee ID - fffe3600320038003300 - Unhappy
# Employee ID - fffe32003200380037003600 - Unhappy
# Employee ID - fffe32003800350031003000 - Unhappy
# Employee ID - fffe3800360036003000 - Happy
# Employee ID - fffe31003300340038003000 - Happy
# Employee ID - fffe32003600350039003700 - Happy
# Employee ID - fffe32003900310031003400 - Happy
# Employee ID - fffe31003900300033003800 - Unhappy
# Employee ID - fffe33003000340030003400 - Happy
# Employee ID - fffe31003800380031003800 - Happy
# Employee ID - fffe31003800350031003600 - Happy
# Employee ID - fffe32003500350036003800 - Happy
# Employee ID - fffe3300390037003000 - Happy
# Employee ID - fffe31003000320037003500 - Unhappy
# Employee ID - fffe32003000370038003000 - Happy
# Employee ID - fffe3500340033003100 - Unhappy
# Employee ID - fffe32003100370039003500 - Happy
# Employee ID - fffe33003200330035003500 - Unhappy
# Employee ID - fffe32003900300033003100 - Happy
# Employee ID - fffe31003200310032003100 - Unhappy
# Employee ID - fffe31003800300032003400 - Unhappy
# Employee ID - fffe33003300310034003600 - Unhappy
# Employee ID - fffe33003400320039003100 - Happy
# Employee ID - fffe31003100320032003300 - Unhappy
# Employee ID - fffe31003100310034003200 - Unhappy
# Employee ID - fffe31003600390034003400 - Happy
# Employee ID - fffe31003600340033003600 - Happy
# Employee ID - fffe32003000390038003800 - Happy
# Employee ID - fffe31003100340038003400 - Happy
# Employee ID - fffe31003700370036003800 - Happy
# Employee ID - fffe3900350032003900 - Unhappy
# Employee ID - fffe31003000300036003800 - Unhappy
# Employee ID - fffe32003700300030003400 - Happy
# Employee ID - fffe31003800360036003600 - Unhappy
# Employee ID - fffe3700380031003100 - Happy
# Employee ID - fffe3100310036003000 - Unhappy
# Employee ID - fffe31003800380038003200 - Unhappy
# Employee ID - fffe33003200390033003400 - Happy
# Employee ID - fffe3500390039003100 - Unhappy
# Employee ID - fffe33003300310030003400 - Happy
# Employee ID - fffe31003500350035003000 - Unhappy
# Employee ID - fffe33003200330037003100 - Unhappy
# Employee ID - fffe33003200360031003500 - Happy
# Employee ID - fffe32003800360039003200 - Happy
# Employee ID - fffe31003600350035003000 - Unhappy
# Employee ID - fffe32003500300037003400 - Happy
# Employee ID - fffe3200330034003300 - Happy
# Employee ID - fffe31003100380032003200 - Unhappy
# Employee ID - fffe33003100340031003200 - Happy
# Employee ID - fffe33003400300036003400 - Unhappy
# Employee ID - fffe31003800310032003800 - Unhappy
# Employee ID - fffe3900380030003500 - Happy
# Employee ID - fffe31003600310036003900 - Unhappy
# Employee ID - fffe3600320039003300 - Unhappy
# Employee ID - fffe32003500340037003800 - Unhappy
# Employee ID - fffe31003800390033003000 - Unhappy
# Employee ID - fffe32003400340033003200 - Unhappy
# Employee ID - fffe31003400370034003600 - Happy
# Employee ID - fffe33003000300030003900 - Unhappy
# Employee ID - fffe32003800350033003100 - Happy
# Employee ID - fffe3100320036003200 - Unhappy
# Employee ID - fffe32003500330034003900 - Unhappy
# Employee ID - fffe3800380036003800 - Happy
# Employee ID - fffe31003300360033003700 - Unhappy
# Employee ID - fffe32003500390031003200 - Unhappy
# Employee ID - fffe3500320034003600 - Happy
# Employee ID - fffe32003500310034003800 - Happy
# Employee ID - fffe3700320038003100 - Unhappy
# Employee ID - fffe33003400330039003900 - Happy
# Employee ID - fffe3500390036003800 - Unhappy
# Employee ID - fffe3600370039003100 - Happy
# Employee ID - fffe32003000370035003200 - Unhappy
# Employee ID - fffe31003400320039003800 - Unhappy
# Employee ID - fffe31003100340030003900 - Unhappy
# Employee ID - fffe32003300310039003600 - Happy
# Employee ID - fffe3600390033003800 - Happy
# Employee ID - fffe3300380038003700 - Happy
# Employee ID - fffe32003600330038003100 - Happy
# Employee ID - fffe31003600390034003300 - Happy
# Employee ID - fffe33003200390030003000 - Happy
# Employee ID - fffe33003400320036003200 - Happy
# Employee ID - fffe32003600330037003800 - Happy
# Employee ID - fffe31003800370037003000 - Happy
# Employee ID - fffe3400340038003800 - Happy
# Employee ID - fffe32003700390031003800 - Happy
# Employee ID - fffe31003300360030003300 - Happy
# Employee ID - fffe32003200310032003000 - Happy
# Employee ID - fffe32003600370030003900 - Happy
# Employee ID - fffe3100350036003500 - Happy
# Employee ID - fffe31003200370037003000 - Happy
# Employee ID - fffe33003400340036003000 - Unhappy
# Employee ID - fffe3200350032003500 - Happy
# Employee ID - fffe350034003400 - Unhappy
# Employee ID - fffe33003400310037003500 - Unhappy
# Employee ID - fffe32003200300037003500 - Happy
# Employee ID - fffe320033003300 - Happy
# Employee ID - fffe3300380035003700 - Happy
# Employee ID - fffe31003100320030003700 - Happy
# Employee ID - fffe3600340037003300 - Happy
# Employee ID - fffe31003100370038003900 - Happy
# Employee ID - fffe3400320038003200 - Unhappy
# Employee ID - fffe3100340036003900 - Happy
# Employee ID - fffe31003500300033003900 - Happy
# Employee ID - fffe31003600350038003100 - Unhappy
# Employee ID - fffe32003800330035003700 - Unhappy
# Employee ID - fffe3100300032003600 - Happy
# Employee ID - fffe33003300330037003700 - Happy
# Employee ID - fffe32003100320031003000 - Happy
# Employee ID - fffe320034003300 - Unhappy
# Employee ID - fffe3700300030003000 - Unhappy
# Employee ID - fffe32003700330031003300 - Happy
# Employee ID - fffe32003200300032003300 - Unhappy
# Employee ID - fffe3100350030003600 - Unhappy
# Employee ID - fffe31003000320030003700 - Happy
# Employee ID - fffe3500360032003600 - Happy
# Employee ID - fffe33003000360030003600 - Unhappy
# Employee ID - fffe31003500370033003300 - Unhappy
# Employee ID - fffe33003400390034003600 - Unhappy
# Employee ID - fffe32003400310034003400 - Unhappy
# Employee ID - fffe31003600340036003900 - Happy
# Employee ID - fffe3400370039003200 - Happy
# Employee ID - fffe3800340031003000 - Happy
# Employee ID - fffe31003800360038003500 - Happy
# Employee ID - fffe3300390039003100 - Happy
# Employee ID - fffe32003700340039003600 - Happy
# Employee ID - fffe32003700320033003500 - Unhappy
# Employee ID - fffe31003200330036003000 - Happy
# Employee ID - fffe31003000350036003000 - Happy
# Employee ID - fffe3400390033003100 - Happy
# Employee ID - fffe32003100370037003600 - Happy
# Employee ID - fffe32003000380036003100 - Unhappy
# Employee ID - fffe32003700320035003100 - Unhappy
# Employee ID - fffe3400320030003700 - Unhappy
# Employee ID - fffe31003700350039003400 - Happy
# Employee ID - fffe31003800340038003400 - Happy
# Employee ID - fffe33003000350033003800 - Unhappy
# Employee ID - fffe33003100390031003900 - Happy
# Employee ID - fffe31003600390034003600 - Unhappy
# Employee ID - fffe3400300039003900 - Happy
# Employee ID - fffe31003000380034003200 - Unhappy
# Employee ID - fffe31003600310036003000 - Happy
# Employee ID - fffe3600300036003000 - Unhappy
# Employee ID - fffe3200370035003000 - Happy
# Employee ID - fffe3200320034003800 - Happy
# Employee ID - fffe32003500380033003000 - Unhappy
# Employee ID - fffe32003200380037003200 - Happy
# Employee ID - fffe32003200380038003000 - Unhappy
# Employee ID - fffe32003700300032003300 - Unhappy
# Employee ID - fffe32003400390036003100 - Unhappy
# Employee ID - fffe3400300038003000 - Unhappy
# Employee ID - fffe33003400390039003600 - Happy
# Employee ID - fffe3900340038003700 - Happy
# Employee ID - fffe33003300370034003400 - Unhappy
# Employee ID - fffe31003300330032003700 - Happy
# Employee ID - fffe31003200300035003200 - Happy
# Employee ID - fffe32003800390030003500 - Happy
# Employee ID - fffe33003000340035003000 - Happy
# Employee ID - fffe3200340030003500 - Happy
# Employee ID - fffe32003800380034003000 - Unhappy
# Employee ID - fffe32003900310037003700 - Unhappy
# Employee ID - fffe3400360031003500 - Unhappy
# Employee ID - fffe3600360037003100 - Unhappy
# Employee ID - fffe32003000310034003500 - Happy
# Employee ID - fffe32003000310037003400 - Happy
# Employee ID - fffe32003300370033003600 - Happy
# Employee ID - fffe3100330031003500 - Unhappy
# Employee ID - fffe32003300300034003200 - Happy
# Employee ID - fffe31003000370033003900 - Happy
# Employee ID - fffe3500330031003100 - Happy
# Employee ID - fffe3600330031003100 - Happy
# Employee ID - fffe3200320035003700 - Unhappy
# Employee ID - fffe33003100300033003200 - Happy
# Employee ID - fffe32003400350039003100 - Happy
# Employee ID - fffe3800360039003000 - Unhappy
# Employee ID - fffe310036003500 - Unhappy
# Employee ID - fffe31003900350032003100 - Happy
# Employee ID - fffe31003800380036003700 - Happy
# Employee ID - fffe31003800320030003800 - Happy
# Employee ID - fffe33003200300037003000 - Happy
# Employee ID - fffe32003900380030003100 - Unhappy
# Employee ID - fffe32003500390034003300 - Happy
# Employee ID - fffe3800370033003200 - Unhappy
# Employee ID - fffe32003000300032003900 - Unhappy
# Employee ID - fffe32003100320031003600 - Happy
# Employee ID - fffe31003700360033003900 - Happy
# Employee ID - fffe33003100310031003900 - Happy
# Employee ID - fffe3300310038003000 - Unhappy
# Employee ID - fffe33003200360033003200 - Unhappy
# Employee ID - fffe32003300370032003200 - Happy
# Employee ID - fffe3100330036003600 - Unhappy
# Employee ID - fffe3600310033003300 - Unhappy
# Employee ID - fffe31003200390031003700 - Happy
# Employee ID - fffe32003300330033003500 - Unhappy
# Employee ID - fffe3800380030003700 - Happy
# Employee ID - fffe3900330032003100 - Unhappy
# Employee ID - fffe32003300350036003200 - Unhappy
# Employee ID - fffe3600380033003200 - Happy
# Employee ID - fffe32003000380034003200 - Unhappy
# Employee ID - fffe32003400350034003500 - Happy
# Employee ID - fffe32003400360031003400 - Happy
# Employee ID - fffe32003800310033003600 - Happy
# Employee ID - fffe31003000390036003400 - Unhappy
# Employee ID - fffe360034003000 - Happy
# Employee ID - fffe31003200390035003300 - Happy
# Employee ID - fffe33003300330034003900 - Happy
# Employee ID - fffe32003900390033003800 - Unhappy
# Employee ID - fffe32003100340030003500 - Unhappy
# Employee ID - fffe3600370037003800 - Happy
# Employee ID - fffe32003000320036003300 - Happy
# Employee ID - fffe31003800370038003500 - Happy
# Employee ID - fffe33003000380039003400 - Happy
# Employee ID - fffe3800320038003000 - Unhappy
# Employee ID - fffe3100340035003800 - Unhappy
# Employee ID - fffe3600320030003500 - Unhappy
# Employee ID - fffe32003200320031003900 - Unhappy
# Employee ID - fffe3600380038003500 - Happy
# Employee ID - fffe31003300300035003200 - Happy
# Employee ID - fffe3800320034003500 - Happy
# Employee ID - fffe32003300340033003100 - Happy
# Employee ID - fffe31003600340032003600 - Happy
# Employee ID - fffe3500380032003000 - Happy
# Employee ID - fffe3900330037003800 - Happy
# Employee ID - fffe33003400360039003000 - Happy
# Employee ID - fffe31003400340032003900 - Unhappy
# Employee ID - fffe33003100370032003400 - Happy
# Employee ID - fffe31003700390036003300 - Unhappy
# Employee ID - fffe33003400380034003600 - Unhappy
# Employee ID - fffe31003400340036003800 - Unhappy
# Employee ID - fffe31003700310034003000 - Unhappy
# Employee ID - fffe32003100 - Happy
# Employee ID - fffe31003500390038003100 - Unhappy
# Employee ID - fffe31003100320034003300 - Unhappy
# Employee ID - fffe3300300032003700 - Happy
# Employee ID - fffe31003000300033003400 - Happy
# Employee ID - fffe32003400300037003000 - Happy
# Employee ID - fffe32003000390039003200 - Unhappy
# Employee ID - fffe32003000320035003700 - Happy
# Employee ID - fffe33003300390034003400 - Happy
# Employee ID - fffe3100320036003700 - Unhappy
# Employee ID - fffe32003200320038003000 - Happy
# Employee ID - fffe32003100380031003900 - Happy
# Employee ID - fffe32003900390030003100 - Happy
# Employee ID - fffe32003700380036003100 - Unhappy
# Employee ID - fffe3600350039003900 - Happy
# Employee ID - fffe32003300320033003100 - Happy
# Employee ID - fffe31003300340032003600 - Unhappy
# Employee ID - fffe360032003500 - Happy
# Employee ID - fffe32003700300036003300 - Unhappy
# Employee ID - fffe31003700350030003000 - Happy
# Employee ID - fffe32003900320039003600 - Unhappy
# Employee ID - fffe32003600350037003700 - Happy
# Employee ID - fffe32003900300030003800 - Happy
# Employee ID - fffe31003200300031003300 - Happy
# Employee ID - fffe33003000390033003700 - Unhappy
# Employee ID - fffe3100300034003000 - Happy
# Employee ID - fffe31003200320032003400 - Happy
# Employee ID - fffe31003100350036003400 - Happy
# Employee ID - fffe3200390033003500 - Happy
# Employee ID - fffe32003800320032003700 - Happy
# Employee ID - fffe31003100300038003400 - Happy
# Employee ID - fffe32003900390039003700 - Unhappy
# Employee ID - fffe3800380039003000 - Happy
# Employee ID - fffe31003800330036003700 - Unhappy
# Employee ID - fffe31003600350033003300 - Happy
# Employee ID - fffe32003700380038003000 - Happy
# Employee ID - fffe32003000330032003500 - Happy
# Employee ID - fffe3800380037003200 - Unhappy
# Employee ID - fffe3100340034003700 - Unhappy
# Employee ID - fffe32003800320030003900 - Happy
# Employee ID - fffe31003700340033003500 - Happy
# Employee ID - fffe32003100390036003200 - Happy
# Employee ID - fffe32003600350034003900 - Happy
# Employee ID - fffe31003600320033003500 - Happy
# Employee ID - fffe3700310036003800 - Happy
# Employee ID - fffe33003300320033003700 - Happy
# Employee ID - fffe31003500380032003300 - Unhappy
# Employee ID - fffe32003400360037003500 - Happy
# Employee ID - fffe3400340033003200 - Happy
# Employee ID - fffe33003000390031003300 - Unhappy
# Employee ID - fffe3300310036003200 - Unhappy
# Employee ID - fffe32003200370033003300 - Unhappy
# Employee ID - fffe3500300039003100 - Unhappy
# Employee ID - fffe33003400300036003000 - Unhappy
# Employee ID - fffe3300370034003000 - Unhappy
# Employee ID - fffe3200300033003300 - Happy
# Employee ID - fffe31003000370033003500 - Happy
# Employee ID - fffe31003400340038003800 - Happy
# Employee ID - fffe3600360034003100 - Unhappy
# Employee ID - fffe32003800390034003500 - Unhappy
# Employee ID - fffe32003200340038003000 - Unhappy
# Employee ID - fffe31003800360039003600 - Unhappy
# Employee ID - fffe3100300031003700 - Happy
# Employee ID - fffe33003400390036003200 - Unhappy
# Employee ID - fffe33003400310031003000 - Happy
# Employee ID - fffe31003500320035003600 - Happy
# Employee ID - fffe31003100360038003100 - Happy
# Employee ID - fffe3900360033003300 - Happy
# Employee ID - fffe33003100340039003400 - Unhappy
# Employee ID - fffe3400390038003800 - Happy
# Employee ID - fffe31003600340032003100 - Unhappy
# Employee ID - fffe33003400380039003300 - Happy
# Employee ID - fffe32003800340036003300 - Happy
# Employee ID - fffe3300330036003300 - Happy
# Employee ID - fffe3700340030003200 - Happy
# Employee ID - fffe3400300035003700 - Happy
# Employee ID - fffe32003200330039003700 - Unhappy
# Employee ID - fffe32003000370031003800 - Happy
# Employee ID - fffe31003200340033003800 - Happy
# Employee ID - fffe31003400330033003900 - Happy
# Employee ID - fffe3700380037003000 - Happy
# Employee ID - fffe3200300031003800 - Happy
# Employee ID - fffe32003900370033003200 - Unhappy
# Employee ID - fffe32003200390034003900 - Unhappy
# Employee ID - fffe33003100340034003000 - Unhappy
# Employee ID - fffe32003800330035003900 - Happy
# Employee ID - fffe3900380033003600 - Unhappy
# Employee ID - fffe32003400380039003600 - Happy
# Employee ID - fffe3200330033003800 - Unhappy
# Employee ID - fffe31003100310030003800 - Happy
# Employee ID - fffe3100390031003600 - Unhappy
# Employee ID - fffe31003500340037003300 - Unhappy
# Employee ID - fffe3300390037003300 - Unhappy
# Employee ID - fffe31003500390030003700 - Unhappy
# Employee ID - fffe3300320030003500 - Happy
# Employee ID - fffe32003000320039003600 - Unhappy
# Employee ID - fffe32003500370036003800 - Happy
# Employee ID - fffe31003400390031003300 - Unhappy
# Employee ID - fffe3800340038003600 - Happy
# Employee ID - fffe31003500320033003800 - Unhappy
# Employee ID - fffe33003100320037003600 - Happy
# Employee ID - fffe32003600390030003500 - Happy
# Employee ID - fffe3100320038003500 - Happy
# Employee ID - fffe3500390038003300 - Happy
# Employee ID - fffe32003200380039003700 - Happy
# Employee ID - fffe380034003600 - Happy
# Employee ID - fffe3600300032003000 - Unhappy
# Employee ID - fffe32003100350031003000 - Happy
# Employee ID - fffe3900300035003400 - Unhappy
# Employee ID - fffe31003200350039003400 - Unhappy
# Employee ID - fffe32003400350035003200 - Unhappy
# Employee ID - fffe31003800370035003400 - Happy
# Employee ID - fffe370036003400 - Unhappy
# Employee ID - fffe3800310034003300 - Happy
# Employee ID - fffe31003100320038003900 - Happy
# Employee ID - fffe32003600340036003900 - Unhappy
# Employee ID - fffe3100390038003300 - Unhappy
# Employee ID - fffe33003200370033003400 - Happy
# Employee ID - fffe3100320030003900 - Happy
# Employee ID - fffe33003400370038003900 - Happy
# Employee ID - fffe3700370030003900 - Happy
# Employee ID - fffe31003200300039003200 - Happy
# Employee ID - fffe3500360032003900 - Happy
# Employee ID - fffe3100340032003600 - Happy
# Employee ID - fffe31003600310037003800 - Happy
# Employee ID - fffe33003000310031003700 - Happy
# Employee ID - fffe31003800360036003700 - Unhappy
# Employee ID - fffe33003100310039003600 - Unhappy
# Employee ID - fffe31003300330031003100 - Happy
# ...
# Employee ID - fffe31003600390032003800 - Happy
# Employee ID - fffe31003300390032003900 - Happy
# Employee ID - fffe31003500380037003700 - Happy
# Employee ID - fffe3600380039003300 - Happy
# Employee ID - fffe33003100310039003500 - Happy
# Employee ID - fffe3800390030003600 - Happy
# Employee ID - fffe32003800380036003400 - Unhappy
# Employee ID - fffe31003300320039003400 - Happy
# Employee ID - fffe32003600340034003200 - Unhappy
# Employee ID - fffe33003400350039003200 - Happy
# Employee ID - fffe3600340030003900 - Happy
# Employee ID - fffe31003800310039003300 - Happy
# Employee ID - fffe31003800330033003600 - Happy
# Employee ID - fffe33003400360035003500 - Unhappy
# Employee ID - fffe31003100310031003700 - Happy
# Employee ID - fffe31003000390032003700 - Unhappy
# Employee ID - fffe3100360034003900 - Happy
# Employee ID - fffe3100380038003400 - Happy
# Employee ID - fffe33003400370031003100 - Happy
# Employee ID - fffe32003400330035003600 - Happy
# Employee ID - fffe32003300360035003900 - Happy
# Employee ID - fffe3400390034003400 - Unhappy
# Employee ID - fffe31003600360033003700 - Unhappy
# Employee ID - fffe31003500310038003600 - Unhappy
# Employee ID - fffe31003300360036003400 - Happy
# Employee ID - fffe3500380037003900 - Unhappy
# Employee ID - fffe31003000340037003800 - Happy
# Employee ID - fffe3400330036003600 - Unhappy
# Employee ID - fffe3600360038003800 - Unhappy
# Employee ID - fffe31003600390030003800 - Unhappy
# Employee ID - fffe32003900310038003400 - Unhappy
# Employee ID - fffe31003600380032003900 - Unhappy
# Employee ID - fffe32003700350034003700 - Happy
# Employee ID - fffe31003000390037003600 - Happy
# Employee ID - fffe33003100320031003200 - Happy
# Employee ID - fffe32003900350038003600 - Unhappy
# Employee ID - fffe3200370033003100 - Happy
# Employee ID - fffe33003200340037003400 - Unhappy
# Employee ID - fffe32003000360032003500 - Happy
# Employee ID - fffe33003200340037003000 - Happy
# Employee ID - fffe32003800350037003800 - Happy
# Employee ID - fffe3400330032003400 - Happy
# Employee ID - fffe3100330037003700 - Happy
# Employee ID - fffe3700320036003500 - Happy
# Employee ID - fffe32003800320034003500 - Unhappy
# Employee ID - fffe32003400370033003200 - Happy
# Employee ID - fffe31003000380038003400 - Unhappy
# Employee ID - fffe3800360036003600 - Happy
# Employee ID - fffe3500360033003000 - Happy
# Employee ID - fffe31003800310034003000 - Unhappy
# Employee ID - fffe3100310031003900 - Happy
# Employee ID - fffe31003600310037003200 - Unhappy
# Employee ID - fffe32003400310035003900 - Unhappy
# Employee ID - fffe32003600340032003600 - Unhappy
# Employee ID - fffe3500370035003700 - Happy
# Employee ID - fffe32003600300037003600 - Happy
# Employee ID - fffe32003200310034003300 - Happy
# Employee ID - fffe32003700380030003100 - Unhappy
# Employee ID - fffe3800320034003700 - Happy
# Employee ID - fffe32003000380036003600 - Unhappy
# Employee ID - fffe33003200340031003400 - Happy
# Employee ID - fffe32003000310030003800 - Unhappy
# Employee ID - fffe340036003800 - Happy
# Employee ID - fffe32003000320033003500 - Unhappy
# Employee ID - fffe3700380039003400 - Happy
# Employee ID - fffe3800310036003800 - Unhappy
# Employee ID - fffe3600360036003400 - Happy
# Employee ID - fffe32003600300035003800 - Unhappy
# Employee ID - fffe32003700310037003900 - Happy
# Employee ID - fffe31003700360033003700 - Happy
# Employee ID - fffe32003600360039003500 - Happy
# Employee ID - fffe3600380037003900 - Happy
# Employee ID - fffe32003900380039003700 - Unhappy
# Employee ID - fffe32003000370031003100 - Happy
# Employee ID - fffe32003700330038003200 - Unhappy
# Employee ID - fffe31003600330034003700 - Happy
# Employee ID - fffe31003900300036003700 - Unhappy
# Employee ID - fffe33003100350034003300 - Unhappy
# Employee ID - fffe32003000380031003900 - Happy
# Employee ID - fffe31003700340034003000 - Unhappy
# Employee ID - fffe31003300330039003800 - Unhappy
# Employee ID - fffe31003200350030003200 - Happy
# Employee ID - fffe31003800300035003800 - Happy
# Employee ID - fffe31003500380033003600 - Happy
# Employee ID - fffe3400380036003500 - Happy
# Employee ID - fffe31003500390032003800 - Happy
# Employee ID - fffe3500320039003400 - Unhappy
# Employee ID - fffe33003400360030003200 - Happy
# Employee ID - fffe31003600360035003700 - Happy
# Employee ID - fffe31003000330037003900 - Unhappy
# Employee ID - fffe3300380034003900 - Happy
# Employee ID - fffe3600370033003300 - Happy
# Employee ID - fffe33003200300030003100 - Happy
# Employee ID - fffe31003700380030003600 - Unhappy
# Employee ID - fffe33003000350038003900 - Unhappy
# Employee ID - fffe350032003000 - Happy
# Employee ID - fffe3600310033003700 - Unhappy
# Employee ID - fffe31003300320036003800 - Happy
# Employee ID - fffe32003400340039003300 - Unhappy
# Employee ID - fffe3100350032003200 - Unhappy
# Employee ID - fffe32003800340037003500 - Unhappy
# Employee ID - fffe3900370039003100 - Happy
# Employee ID - fffe31003700390033003300 - Happy
# Employee ID - fffe32003600350033003000 - Unhappy
# Employee ID - fffe32003400380030003000 - Unhappy
# Employee ID - fffe33003300350032003500 - Happy
# Employee ID - fffe31003900370039003600 - Happy
# Employee ID - fffe3900360034003200 - Happy
# Employee ID - fffe3600380035003100 - Happy
# Employee ID - fffe31003600380030003200 - Unhappy
# Employee ID - fffe31003300300039003100 - Happy
# Employee ID - fffe33003200340039003700 - Happy
# Employee ID - fffe31003700360037003000 - Unhappy
# Employee ID - fffe3800320032003400 - Unhappy
# Employee ID - fffe33003400380032003500 - Happy
# Employee ID - fffe31003700310037003100 - Happy
# Employee ID - fffe31003200360031003600 - Happy
# Employee ID - fffe32003800380035003100 - Happy
# Employee ID - fffe370032003000 - Unhappy
# Employee ID - fffe31003600320035003100 - Happy
# Employee ID - fffe31003800350031003100 - Unhappy
# Employee ID - fffe3100330030003800 - Unhappy
# Employee ID - fffe32003800310038003600 - Unhappy
# Employee ID - fffe31003600340038003000 - Happy
# Employee ID - fffe33003400360030003400 - Unhappy
# Employee ID - fffe3700300039003900 - Unhappy
# Employee ID - fffe33003100350038003300 - Happy
# Employee ID - fffe32003900320035003200 - Happy
# Employee ID - fffe33003400310038003100 - Unhappy
# Employee ID - fffe31003800310030003300 - Unhappy
# Employee ID - fffe33003200390032003900 - Happy
# Employee ID - fffe32003300350039003900 - Happy
# Employee ID - fffe31003800350039003600 - Happy
# Employee ID - fffe32003200360030003300 - Happy
# Employee ID - fffe33003200350037003700 - Happy
# Employee ID - fffe32003100350035003800 - Happy
# Employee ID - fffe31003700300037003000 - Happy
# Employee ID - fffe32003200380039003900 - Unhappy
# Employee ID - fffe32003300300033003700 - Happy
# Employee ID - fffe31003100370031003500 - Unhappy
# Employee ID - fffe31003100350032003400 - Unhappy
# Employee ID - fffe31003400350038003500 - Happy
# Employee ID - fffe33003000300038003600 - Unhappy
# Employee ID - fffe31003400380036003400 - Happy
# Employee ID - fffe3200350035003900 - Happy
# Employee ID - fffe33003000320033003100 - Happy
# Employee ID - fffe33003200330038003200 - Happy
# Employee ID - fffe3200380033003300 - Happy
# Employee ID - fffe3900380032003900 - Unhappy
# Employee ID - fffe3600360038003300 - Happy
# Employee ID - fffe33003300350034003200 - Unhappy
# Employee ID - fffe3200330039003300 - Happy
# Employee ID - fffe3400340036003900 - Unhappy
# Employee ID - fffe31003800360030003400 - Happy
# Employee ID - fffe31003700320038003500 - Unhappy
# Employee ID - fffe32003100320030003400 - Happy
# Employee ID - fffe32003800320037003500 - Happy
# Employee ID - fffe3100390034003500 - Happy
# Employee ID - fffe3900350030003100 - Happy
# Employee ID - fffe32003300380039003100 - Unhappy
# Employee ID - fffe32003400330039003800 - Happy
# Employee ID - fffe31003800370031003500 - Happy
# Employee ID - fffe33003300370035003400 - Happy
# Employee ID - fffe31003600330035003600 - Happy
# Employee ID - fffe31003100380035003100 - Unhappy
# Employee ID - fffe3900360033003000 - Happy
# Employee ID - fffe32003100300031003900 - Happy
# Employee ID - fffe31003200370034003700 - Happy
# Employee ID - fffe32003100330030003900 - Happy
# Employee ID - fffe31003000330039003200 - Happy
# Employee ID - fffe3300350033003800 - Happy
# Employee ID - fffe31003600350037003200 - Unhappy
# Employee ID - fffe32003800310039003300 - Unhappy
# Employee ID - fffe31003500380038003700 - Happy
# Employee ID - fffe33003100330037003800 - Unhappy
# Employee ID - fffe32003100350030003900 - Happy
# Employee ID - fffe3700350035003300 - Happy
# Employee ID - fffe3800350030003000 - Unhappy
# Employee ID - fffe3400350035003900 - Happy
# Employee ID - fffe3800390035003900 - Happy
# Employee ID - fffe33003400390037003500 - Happy
# Employee ID - fffe3300340035003500 - Unhappy
# Employee ID - fffe3500330031003400 - Happy
# Employee ID - fffe31003000330037003800 - Unhappy
# Employee ID - fffe33003300330037003300 - Unhappy
# Employee ID - fffe31003200340031003500 - Unhappy
# Employee ID - fffe3600360036003300 - Happy
# Employee ID - fffe33003200380033003700 - Happy
# Employee ID - fffe32003100330033003000 - Happy
# Employee ID - fffe33003100380033003300 - Happy
# Employee ID - fffe33003100350032003600 - Unhappy
# Employee ID - fffe32003500340032003900 - Happy
# Employee ID - fffe32003700390038003400 - Unhappy
# Employee ID - fffe31003600330037003900 - Happy
# Employee ID - fffe3700340031003300 - Happy
# Employee ID - fffe32003700360038003300 - Unhappy
# Employee ID - fffe3400320033003800 - Happy
# Employee ID - fffe3600320034003500 - Happy
# Employee ID - fffe31003300310038003600 - Unhappy
# Employee ID - fffe31003500330037003000 - Happy
# Employee ID - fffe3800380037003300 - Unhappy
# Employee ID - fffe33003200300034003400 - Happy
# Employee ID - fffe3800310034003100 - Happy
# Employee ID - fffe32003800340032003800 - Unhappy
# Employee ID - fffe360038003600 - Happy
# Employee ID - fffe33003000350036003000 - Happy
# Employee ID - fffe31003500300032003900 - Happy
# Employee ID - fffe31003300360033003100 - Happy
# Employee ID - fffe32003900310038003500 - Happy
# Employee ID - fffe31003400320030003600 - Happy
# Employee ID - fffe3700360036003300 - Happy
# Employee ID - fffe3300330033003200 - Happy
# Employee ID - fffe3300380036003700 - Happy
# Employee ID - fffe31003200390031003600 - Happy
# Employee ID - fffe3200390032003800 - Unhappy
# Employee ID - fffe33003100380033003100 - Unhappy
# Employee ID - fffe33003300300033003200 - Happy
# Employee ID - fffe32003400390031003100 - Happy
# Employee ID - fffe32003000330031003300 - Happy
# Employee ID - fffe31003700370036003500 - Happy
# Employee ID - fffe32003800350031003600 - Happy
# Employee ID - fffe33003400330030003300 - Unhappy
# Employee ID - fffe33003400330032003700 - Happy
# Employee ID - fffe31003800330038003700 - Unhappy
# Employee ID - fffe31003500350039003500 - Happy
# Employee ID - fffe31003600390037003200 - Happy
# Employee ID - fffe3200380037003000 - Happy
# Employee ID - fffe32003200380030003900 - Unhappy
# Employee ID - fffe3700360030003200 - Happy
# Employee ID - fffe32003900340038003400 - Unhappy
# Employee ID - fffe32003800390039003500 - Unhappy
# Employee ID - fffe31003300320031003100 - Happy
# Employee ID - fffe32003500300036003200 - Happy
# Employee ID - fffe3900360038003800 - Happy
# Employee ID - fffe32003600330033003500 - Happy
# Employee ID - fffe32003200310032003300 - Unhappy
# Employee ID - fffe3700320031003100 - Unhappy
# Employee ID - fffe32003500340039003400 - Happy
# Employee ID - fffe33003400350037003800 - Happy
# Employee ID - fffe3400370037003900 - Unhappy
# Employee ID - fffe31003400390039003400 - Unhappy
# Employee ID - fffe32003300340031003200 - Happy
# Employee ID - fffe380038003200 - Happy
# Employee ID - fffe31003100330035003400 - Unhappy
# Employee ID - fffe3400320035003900 - Unhappy
# Employee ID - fffe3500360037003400 - Happy
# Employee ID - fffe32003400350036003600 - Happy
# Employee ID - fffe32003900310034003900 - Happy
# Employee ID - fffe31003000300038003400 - Unhappy
# Employee ID - fffe3900350037003700 - Unhappy
# Employee ID - fffe31003500300036003000 - Happy
# Employee ID - fffe390035003900 - Happy
# Employee ID - fffe32003400390032003100 - Happy
# Employee ID - fffe3200350037003900 - Happy
# Employee ID - fffe31003000380034003700 - Unhappy
# Employee ID - fffe31003100360037003500 - Unhappy
# Employee ID - fffe3600310034003600 - Happy
# Employee ID - fffe32003000330039003100 - Unhappy
# Employee ID - fffe31003100320037003100 - Happy
# Employee ID - fffe31003000380033003300 - Unhappy
# Employee ID - fffe3700340039003300 - Happy
# Employee ID - fffe32003100340030003700 - Unhappy
# Employee ID - fffe32003800340032003000 - Happy
# Employee ID - fffe32003300320031003300 - Happy
# Employee ID - fffe32003500350034003300 - Happy
# Employee ID - fffe3600300037003600 - Unhappy
# Employee ID - fffe31003100330037003400 - Unhappy
# Employee ID - fffe3600390033003600 - Happy
# Employee ID - fffe32003900320031003700 - Happy
# Employee ID - fffe3900320038003100 - Happy
# Employee ID - fffe32003400330031003300 - Happy
# Employee ID - fffe3100300039003000 - Happy
# Employee ID - fffe32003800320034003700 - Happy
# Employee ID - fffe32003500300032003900 - Unhappy
# Employee ID - fffe32003400370033003300 - Happy
# Employee ID - fffe3500330035003300 - Happy
# Employee ID - fffe32003700370035003200 - Happy
# Employee ID - fffe3300330038003800 - Happy
# Employee ID - fffe32003900370030003400 - Unhappy
# Employee ID - fffe370037003400 - Happy
# Employee ID - fffe33003300340037003100 - Happy
# Employee ID - fffe3600320035003500 - Unhappy
# Employee ID - fffe33003200330031003300 - Happy
# Employee ID - fffe31003900350030003100 - Unhappy
# Employee ID - fffe31003000350037003500 - Unhappy
# Employee ID - fffe32003300310038003300 - Unhappy
# Employee ID - fffe32003800360038003500 - Unhappy
# Employee ID - fffe3200370031003300 - Happy
# Employee ID - fffe32003300310039003800 - Unhappy
# Employee ID - fffe3200320030003400 - Unhappy
# Employee ID - fffe32003200380033003200 - Happy
# Employee ID - fffe31003500370033003200 - Happy
# Employee ID - fffe31003900360032003200 - Unhappy
# Employee ID - fffe3900380039003500 - Unhappy
# Employee ID - fffe32003100390032003600 - Unhappy
# Employee ID - fffe32003800390037003700 - Unhappy
# Employee ID - fffe3800340031003100 - Happy
# Employee ID - fffe33003300370031003200 - Unhappy
# Employee ID - fffe3900390032003300 - Happy
# Employee ID - fffe33003200390033003800 - Happy
# Employee ID - fffe350035003300 - Unhappy
# Employee ID - fffe32003500300030003600 - Happy
# Employee ID - fffe31003100350039003100 - Unhappy
# Employee ID - fffe3500370039003000 - Happy
# Employee ID - fffe33003000300035003200 - Unhappy
# Employee ID - fffe3200350031003700 - Unhappy
# Employee ID - fffe3800360032003700 - Unhappy
# Employee ID - fffe31003900370033003400 - Unhappy
# Employee ID - fffe33003000330038003600 - Unhappy
# Employee ID - fffe3100320034003000 - Happy
# Employee ID - fffe32003800370038003500 - Happy
# Employee ID - fffe31003400360035003400 - Unhappy
# Employee ID - fffe33003200380033003500 - Happy
# Employee ID - fffe32003600300034003300 - Happy
# Employee ID - fffe31003000300038003100 - Happy
# Employee ID - fffe3200300037003200 - Happy
# Employee ID - fffe33003100350036003700 - Happy
# Employee ID - fffe33003000360038003200 - Happy
# Employee ID - fffe3200330035003000 - Happy
# Employee ID - fffe31003100320035003800 - Unhappy
# Employee ID - fffe31003700310035003300 - Happy
# Employee ID - fffe3600330038003500 - Happy
# Employee ID - fffe3100300035003100 - Unhappy
# Employee ID - fffe3800300033003800 - Happy
# Employee ID - fffe3200300032003200 - Unhappy
# Employee ID - fffe32003200330031003100 - Unhappy
# Employee ID - fffe32003700310031003500 - Unhappy
# Employee ID - fffe3200340039003400 - Unhappy
# Employee ID - fffe3400350034003800 - Unhappy
# Employee ID - fffe33003200390038003100 - Happy
# Employee ID - fffe33003300300034003900 - Happy
# Employee ID - fffe32003900390030003800 - Happy
# Employee ID - fffe32003400330030003000 - Happy
# Employee ID - fffe32003200370037003300 - Unhappy
# Employee ID - fffe31003300380031003400 - Happy
# Employee ID - fffe3400380037003400 - Happy
# Employee ID - fffe31003700370031003100 - Happy
# Employee ID - fffe31003400370037003000 - Unhappy
# Employee ID - fffe390036003600 - Unhappy
# Employee ID - fffe32003200340034003200 - Unhappy
# Employee ID - fffe32003800350032003400 - Happy
# Employee ID - fffe32003700340037003200 - Happy
# Employee ID - fffe32003100320037003000 - Unhappy
# Employee ID - fffe3400360033003300 - Unhappy
# 3866

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print('Confusion matrix\n\n', cm)

print('\nTrue Negative(TN) = ', cm[0,0])

print('\nFalse Positives(FP) = ', cm[0,1])

print('\nFalse Negative(FN) = ', cm[1,0])

print('\nTrue Positive(TP) = ', cm[1,1])
# Out:
# Confusion matrix
#
#  [[2268  287]
#  [ 354 3579]]
#
# True Negative(TN) =  2268
#
# False Positives(FP) =  287
#
# False Negative(FN) =  354
#
# True Positive(TP) =  3579

# %%
y_test.value_counts()
# Out:
# 1    3933
# 0    2555
# Name: HappyCond, dtype: int64

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, sharey=False, figsize=(10,5))
sns.countplot(df_train["HappyCond"], palette="winter", ax=ax[0]).set_title("Data for Training Model")
sns.countplot(y_test, palette="winter", ax=ax[1]).set_title("Data for Testing Model")
plt.tight_layout()
plt.show()
print("0 : Not Happy")
print("1 : Happy")
# Out:
# 0 : Not Happy
# 1 : Happy

# %%
values = y_test.value_counts().keys().tolist()
counts = y_test.value_counts().tolist()
for i in range(len(values)):
    if values[i] == 0:
        print("Number of 'NOT HAPPY' Employees are: "+str(counts[i]))
    else:
        print("Number of 'HAPPY' Employees are: "+str(counts[i]))
# Out:
# Number of 'HAPPY' Employees are: 3933
# Number of 'NOT HAPPY' Employees are: 2555
